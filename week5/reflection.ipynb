# %%
# Load Library
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Load Image
image = cv2.imread("images/slider_puffin_before_mobile.jpg", cv2.IMREAD_GRAYSCALE)

# %%
# Show Image
plt.imshow(image, cmap="gray"), plt.axis("off")
plt.show()

# %%
image
# Out:
# array([[228, 229, 229, ..., 233, 233, 233],
#        [228, 229, 229, ..., 233, 233, 233],
#        [229, 229, 229, ..., 233, 233, 233],
#        ...,
#        [216, 217, 216, ..., 233, 233, 234],
#        [217, 217, 215, ..., 233, 233, 234],
#        [216, 217, 216, ..., 234, 234, 233]], dtype=uint8)

# %%
# Loading image in Color
image_bgr = cv2.imread("images/slider_puffin_before_mobile.jpg", cv2.IMREAD_COLOR)
# Show Image
plt.imshow(image_bgr, cmap="gray"), plt.axis("on")
plt.show()
